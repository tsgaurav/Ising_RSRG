# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L = 50

for x in range(L):
    for y in range(L):
        plt.scatter(y+(0.25*(-1)**(x%2)), x)
        
        
plt.gca().invert_yaxis()
